# %% [markdown]
# <a href="https://colab.research.google.com/github/fkrabdillah17/JST/blob/main/MLP/Binary%20Classification/Binary_Clasification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# mlp for binary classification
from pandas import read_csv
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

# %%
#load dataset
path = '/content/drive/MyDrive/JST-TugasKe-2/MLP/BinaryClassification/ionosphere.csv'
df = read_csv(path, header=None)
# split into input and output columns
X, y = df.values[:, :-1], df.values[:, -1]
# ensure all data are floating point values
X = X.astype('float32')
# encode strings to integer
y = LabelEncoder().fit_transform(y)
# split into train and test datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# determine the number of input features
n_features = X_train.shape[1]
# Out:
# (235, 34) (116, 34) (235,) (116,)

# %%
# define model
model = Sequential()
model.add(Dense(10, activation='relu', kernel_initializer='he_normal', input_shape=(n_features,)))
model.add(Dense(8, activation='relu', kernel_initializer='he_normal'))
model.add(Dense(1, activation='sigmoid'))
# compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
# fit the model
model.fit(X_train, y_train, epochs=150, batch_size=32, verbose=1)
model_url = '/content/drive/MyDrive/JST-TugasKe-2/MLP/BinaryClassification/Binary_Classification.h5'
model.save(model_url)
print("Saved")
# Out:
# Epoch 1/150
# 8/8 [==============================] - 1s 2ms/step - loss: 0.7371 - accuracy: 0.6596
# Epoch 2/150
# 8/8 [==============================] - 0s 3ms/step - loss: 0.7092 - accuracy: 0.6638
# Epoch 3/150
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6850 - accuracy: 0.6851
# Epoch 4/150
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6597 - accuracy: 0.6851
# Epoch 5/150
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6376 - accuracy: 0.6894
# Epoch 6/150
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6203 - accuracy: 0.6936
# Epoch 7/150
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6043 - accuracy: 0.6979
# Epoch 8/150
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5899 - accuracy: 0.7064
# Epoch 9/150
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5779 - accuracy: 0.7106
# Epoch 10/150
# ...

# %%
loss, acc = model.evaluate(X_test, y_test, verbose=0)
print('Test Accuracy: %.3f' % acc)
# Out:
# Test Accuracy: 0.922

# %%
# make a prediction
row = [1,0,0.99539,-0.05889,0.85243,0.02306,0.83398,-0.37708,1,0.03760,0.85243,-0.17755,0.59755,-0.44945,0.60536,-0.38223,0.84356,-0.38542,0.58212,-0.32192,0.56971,-0.29674,0.36946,-0.47357,0.56811,-0.51171,0.41078,-0.46168,0.21266,-0.34090,0.42267,-0.54487,0.18641,-0.45300]
yhat = model.predict([row])
print('Predicted: %.3f' % yhat)
# Out:
# Predicted: 0.941
