# %% [markdown]
# <a href="https://colab.research.google.com/github/fkrabdillah17/JST/blob/main/MLP/Regression/MLP_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Regression Example With Boston Dataset: Baseline
from pandas import read_csv
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
# load dataset
dataframe = read_csv("/content/drive/MyDrive/JST-TugasKe-2/MLP/Regression/housing.csv", delim_whitespace=True, header=None)
dataset = dataframe.values
# split into input (X) and output (Y) variables
X = dataset[:,0:13]
Y = dataset[:,13]
# define base model
def baseline_model():
	# create model
	model = Sequential()
	model.add(Dense(13, input_dim=13, kernel_initializer='normal', activation='relu'))
	model.add(Dense(1, kernel_initializer='normal'))
	# Compile model
	model.compile(loss='mean_squared_error', optimizer='adam')
	return model

model = baseline_model()
model_url = '/content/drive/MyDrive/JST-TugasKe-2/MLP/Regression/RegressionModel.h5'
model.save(model_url)
print("Saved")
# evaluate model
estimator = KerasRegressor(build_fn=baseline_model, epochs=25, batch_size=5, verbose=1)
kfold = KFold(n_splits=10)
results = cross_val_score(estimator, X, Y, cv=kfold)
print("Baseline: %.2f (%.2f) MSE" % (results.mean(), results.std()))
# Out:
# Saved
# Epoch 1/25
# 91/91 [==============================] - 1s 1ms/step - loss: 343.8365
# Epoch 2/25
# 91/91 [==============================] - 0s 1ms/step - loss: 118.0824
# Epoch 3/25
# 91/91 [==============================] - 0s 1ms/step - loss: 108.8485
# Epoch 4/25
# 91/91 [==============================] - 0s 1ms/step - loss: 67.6976
# Epoch 5/25
# 91/91 [==============================] - 0s 1ms/step - loss: 64.7422
# Epoch 6/25
# 91/91 [==============================] - 0s 1ms/step - loss: 69.9254
# Epoch 7/25
# 91/91 [==============================] - 0s 1ms/step - loss: 66.6827
# Epoch 8/25
# 91/91 [==============================] - 0s 1ms/step - loss: 54.0869
# Epoch 9/25
# 91/91 [==============================] - 0s 1ms/step - loss: 58.2955
# Epoch 10/25
# 91/91 [==============================] - 0s 1ms/step - loss: 41.9022
# Epoch 11/25
# 91/91 [==============================] - 0s 1ms/step - loss: 62.3910
# Epoch 12/25
# ...
